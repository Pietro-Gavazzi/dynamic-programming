# %%
import numpy as np
import pandas as pd



list_x = []
list_mean = []
for  i in range(100000):

    x = np.random.normal(2, 2, 3)
    barx = np.mean(x)
    list_mean.append(barx)
    nx = np.random.normal(2,2)
    list_x.append(barx-nx)

print(np.mean(list_x))
print(np.std(list_x))
# Out:
# -0.0032785683539580386
# 2.3097037523982458

# %%
pd.DataFrame(list_x).hist(bins=60)
np.sqrt(16/3)
# Out:
# 2.309401076758503
